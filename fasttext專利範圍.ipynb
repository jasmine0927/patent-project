# %%
import fasttext
import pandas as pd
import numpy as np
from numpy.linalg import norm

# %%
# 加載 FastText 模型
model = fasttext.load_model(r"C:\Users\nicon\Downloads\cc.zh.300.bin\cc.zh.300.bin")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# 讀取專利草稿構面和專利構面資料
draft_df = pd.read_excel('專利草稿構面.xlsx')
patents_df = pd.read_excel('專利構面.xlsx')

# %%
# 只處理“專利範圍”欄位
draft_text = draft_df['專利範圍'].iloc[0]
draft_vector = np.squeeze(np.asarray(model.get_sentence_vector(draft_text)))

# %%
# 計算相似度並存儲結果
similarities = []
for idx, row in patents_df.iterrows():
    patent_text = str(row['專利範圍'])
    patent_vector = np.squeeze(np.asarray(model.get_sentence_vector(patent_text)))
    similarity = np.dot(draft_vector, patent_vector) / (norm(draft_vector) * norm(patent_vector))
    similarities.append((idx, similarity))

# %%
# 按相似度排序並輸出結果
similarities.sort(key=lambda x: x[1], reverse=True)
for idx, similarity in similarities:
    print(f"Index: {idx+1}, Similarity: {similarity}")
# Out:
# Index: 85, Similarity: 1.0
# Index: 84, Similarity: 0.83697909116745
# Index: 36, Similarity: 0.8338188529014587
# Index: 67, Similarity: 0.8270559906959534
# Index: 44, Similarity: 0.8246893882751465
# Index: 21, Similarity: 0.820712685585022
# Index: 11, Similarity: 0.8193528652191162
# Index: 31, Similarity: 0.8192628026008606
# Index: 5, Similarity: 0.8176846504211426
# Index: 24, Similarity: 0.8163091540336609
# Index: 82, Similarity: 0.8135959506034851
# Index: 23, Similarity: 0.8122254610061646
# Index: 69, Similarity: 0.8119325637817383
# Index: 86, Similarity: 0.8115552067756653
# Index: 20, Similarity: 0.8078941702842712
# Index: 28, Similarity: 0.80672287940979
# Index: 17, Similarity: 0.8063183426856995
# Index: 77, Similarity: 0.8061522245407104
# Index: 49, Similarity: 0.8060015439987183
# Index: 6, Similarity: 0.8058058023452759
# Index: 54, Similarity: 0.8028821349143982
# Index: 100, Similarity: 0.8006455898284912
# Index: 7, Similarity: 0.7999176979064941
# Index: 34, Similarity: 0.7981445789337158
# Index: 30, Similarity: 0.7973597645759583
# Index: 78, Similarity: 0.7949724793434143
# Index: 13, Similarity: 0.7918125987052917
# Index: 72, Similarity: 0.7916275262832642
# Index: 87, Similarity: 0.7900924682617188
# Index: 8, Similarity: 0.7896807193756104
# Index: 97, Similarity: 0.7891726493835449
# Index: 55, Similarity: 0.7888041734695435
# Index: 64, Similarity: 0.7884594202041626
# Index: 91, Similarity: 0.7884455323219299
# Index: 74, Similarity: 0.7871893048286438
# Index: 9, Similarity: 0.7871050834655762
# Index: 88, Similarity: 0.7849188446998596
# Index: 32, Similarity: 0.7844835519790649
# Index: 81, Similarity: 0.7821000218391418
# Index: 47, Similarity: 0.7819728255271912
# Index: 63, Similarity: 0.7807163000106812
# Index: 56, Similarity: 0.777812123298645
# Index: 4, Similarity: 0.7777186036109924
